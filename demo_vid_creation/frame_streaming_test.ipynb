# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import joblib
print(tf.__version__)
# Out:
# WARNING:tensorflow:From c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
# Load the trained LSTM model
model = tf.keras.models.load_model("./lstm/lstm_latency_model.keras")
print("Model loaded successfully!")

# Load the saved scaler
scaler = joblib.load("./lstm/minmax_scaler.pkl")
print("Scaler loaded successfully!")

# Function to compute differences
def compute_differences(df):
    df = df.copy()
    df["motion_score_diff"] = df["motion_score"].diff().fillna(0)
    df["flow_magnitude_diff"] = df["flow_magnitude"].diff().fillna(0)
    return df

# Function to prepare data for LSTM prediction
def prepare_data_for_model(df, scaler, features):
    df_normalized = df.copy()
    df_normalized[features] = scaler.transform(df[features])
    X = df_normalized[features].values
    X = X.reshape((X.shape[0], 1, X.shape[1]))
    return X

# Function to preprocess frames with a sliding window of 2 and predict incrementally
def preprocess_n_predict(frame_files, scaler, model, frame_window=2):
    if frame_window != 2:
        print("Error: This implementation is designed for a window size of 2 only.")
        return None
    
    if len(frame_files) < 2:
        print("Error: At least 2 frames are required for processing.")
        return None
    
    features = ["time_stamp", "motion_score", "motion_score_diff", "flow_magnitude", "flow_magnitude_diff"]
    
    # Process frames in sliding windows of 2
    for start_idx in range(0, len(frame_files) - 1, 1):  # Slide by 1 frame each time
        data = []
        prev_gray = None
        
        # Process the current pair of frames (window of 2)
        for i in range(start_idx, min(start_idx + frame_window, len(frame_files))):
            frame_file = frame_files[i]
            #print(f"Processing frame {i+1}/{len(frame_files)}: {os.path.basename(frame_file)}")
            frame = cv2.imread(frame_file)
            if frame is None:
                print(f"Warning: Could not read frame {frame_file}")
                continue
            
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            
            if prev_gray is not None:
                # Compute motion metrics for the second frame in the pair
                diff = cv2.absdiff(prev_gray, gray)
                _, diff_thresh = cv2.threshold(diff, 50, 255, cv2.THRESH_BINARY)
                motion_score = np.sum(diff_thresh) / 255

                flow = cv2.calcOpticalFlowFarneback(prev_gray, gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
                flow_magnitude = np.linalg.norm(flow, axis=2).mean()

                timestamp = int(os.path.basename(frame_file).split('_')[-1].split('.')[0])
                
                data.append({
                    "frame": i,
                    "file_name": os.path.basename(frame_file),
                    "motion_score": motion_score,
                    "flow_magnitude": flow_magnitude,
                    "time_stamp": timestamp
                })
            
            prev_gray = gray
            del frame
        
        # Create DataFrame for the current pair
        df = pd.DataFrame(data)
        if df.empty:
            print(f"Skipping window starting at frame {start_idx}: No valid data processed.")
            continue
        
        #print(f"Processed {len(data)} frames into DataFrame for window starting at frame {start_idx}")
        
        # Compute differences
        df = compute_differences(df)
        
        # Prepare data for model
        X = prepare_data_for_model(df, scaler, features)
        
        # Make predictions
        print("Making predictions for current window...")
        predictions = model.predict(X, verbose=1)
        predicted_labels = (predictions > 0.5).astype(int)
        
        # Print results for this window
        print("\nPrediction Results for Window:")
        print("Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence")
        print("-" * 130)
        for j in range(len(predictions)):
            frame_info = df.iloc[j]
            pred_label = "0ms" if predicted_labels[j] == 0 else "200ms"
            confidence = predictions[j][0]
            print(f"{frame_info['frame']:5d} | {frame_info['file_name'][:20]:20s} | {frame_info['motion_score']:12.2f} | "
                  f"{frame_info['flow_magnitude']:13.6f} | {frame_info['motion_score_diff']:17.2f} | "
                  f"{frame_info['flow_magnitude_diff']:19.6f} | {pred_label:15s} | {confidence:.6f}")
        print("\n" + "=" * 50 + "\n")  # Separator between windows
    
    return None
# Out:
# WARNING:tensorflow:From c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model loaded successfully!
# Scaler loaded successfully!

# %%
folder_path = "./raw_data_parsing/game_frames_200ms/game_frames_200ms"
frame_files = sorted([os.path.join(folder_path, f) for f in os.listdir(folder_path) 
                          if f.endswith(('.png', '.jpg', '.jpeg'))])
preprocess_n_predict(frame_files, scaler, model, frame_window=2)
# Out:
# Making predictions for current window...
# 1/1 [==============================] - 0s 31ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     1 | 172_19_113_65_174210 |       400.00 |      1.119061 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 32ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     2 | 172_19_113_65_174210 |       453.00 |      1.629436 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 33ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     3 | 172_19_113_65_174210 |       278.00 |      1.141239 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 31ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     4 | 172_19_113_65_174210 |       315.00 |      1.140899 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 30ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     5 | 172_19_113_65_174210 |       308.00 |      1.120610 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 32ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     6 | 172_19_113_65_174210 |       400.00 |      1.652544 |              0.00 |            0.000000 | 200ms           | 0.999999
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 33ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     7 | 172_19_113_65_174210 |       156.00 |      0.139384 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 31ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     8 | 172_19_113_65_174210 |       124.00 |      0.037683 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 36ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#     9 | 172_19_113_65_174210 |       186.00 |      0.030341 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 39ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    10 | 172_19_113_65_174210 |       156.00 |      0.024651 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 31ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    11 | 172_19_113_65_174210 |       102.00 |      0.017617 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 29ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    12 | 172_19_113_65_174210 |       168.00 |      0.024712 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 33ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    13 | 172_19_113_65_174210 |        38.00 |      0.019206 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 34ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    14 | 172_19_113_65_174210 |        68.00 |      0.023200 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 41ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    15 | 172_19_113_65_174210 |        84.00 |      0.023091 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 37ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    16 | 172_19_113_65_174210 |       114.00 |      0.026755 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 33ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    17 | 172_19_113_65_174210 |        55.00 |      0.017223 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 26ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    18 | 172_19_113_65_174210 |       124.00 |      0.026024 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 32ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    19 | 172_19_113_65_174210 |       138.00 |      0.031844 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 31ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    20 | 172_19_113_65_174210 |        94.00 |      0.015320 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 34ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    21 | 172_19_113_65_174210 |     15485.00 |      1.868348 |              0.00 |            0.000000 | 200ms           | 0.999999
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 32ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    22 | 172_19_113_65_174210 |     16393.00 |      2.619328 |              0.00 |            0.000000 | 200ms           | 0.999999
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 36ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    23 | 172_19_113_65_174210 |       808.00 |      1.044584 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 35ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    24 | 172_19_113_65_174210 |       439.00 |      0.904614 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 33ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    25 | 172_19_113_65_174210 |        97.00 |      0.404411 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 31ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    26 | 172_19_113_65_174210 |        91.00 |      0.289468 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 32ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    27 | 172_19_113_65_174210 |       875.00 |      0.542953 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 35ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    28 | 172_19_113_65_174210 |       207.00 |      0.297426 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 35ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    29 | 172_19_113_65_174210 |       440.00 |      0.477251 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 37ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    30 | 172_19_113_65_174210 |       893.00 |      0.757901 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 34ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    31 | 172_19_113_65_174210 |       603.00 |      0.884706 |              0.00 |            0.000000 | 200ms           | 0.999998
#
# ==================================================
#
# Making predictions for current window...
# 1/1 [==============================] - 0s 35ms/step
#
# Prediction Results for Window:
# Frame | File Name            | Motion Score | Flow Magnitude | Motion Score Diff | Flow Magnitude Diff | Predicted Latency | Confidence
# ----------------------------------------------------------------------------------------------------------------------------------
#    32 | 172_19_113_65_174210 |       739.00 |      1.063346 |              0.00 |            0.000000 | 200ms           | 0.999999
#
# ==================================================
#
# Making predictions for current window...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 folder_path = "./raw_data_parsing/game_frames_200ms/game_frames_200ms"
#       2 frame_files = sorted([os.path.join(folder_path, f) for f in os.listdir(folder_path)
#       3                           if f.endswith(('.png', '.jpg', '.jpeg'))])
# ----> 4 preprocess_n_predict(frame_files, scaler, model, frame_window=2)
#
# Cell In[4], line 90, in preprocess_n_predict(frame_files, scaler, model, frame_window)
#      88 # Make predictions
#      89 print("Making predictions for current window...")
# ---> 90 predictions = model.predict(X, verbose=1)
#      91 predicted_labels = (predictions > 0.5).astype(int)
#      93 # Print results for this window
#
# File c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\keras\src\engine\training.py:2651, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2649     self._steps_per_execution_tuner.start()
#    2650 batch_outputs = None
# -> 2651 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2652     with data_handler.catch_stop_iteration():
#    2653         for step in data_handler.steps():
#
# File c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\keras\src\engine\data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:500, in DatasetV2.__iter__(self)
#     498 if context.executing_eagerly() or ops.inside_function():
#     499   with ops.colocate_with(self._variant_tensor):
# --> 500     return iterator_ops.OwnedIterator(self)
#     501 else:
#     502   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     503                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:706, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     702   if (components is not None or element_spec is not None):
#     703     raise ValueError(
#     704         "When `dataset` is provided, `element_spec` and `components` must "
#     705         "not be specified.")
# --> 706   self._create_iterator(dataset)
#     708 self._get_next_call_count = 0
#
# File c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:745, in OwnedIterator._create_iterator(self, dataset)
#     742   assert len(fulltype.args[0].args[0].args) == len(
#     743       self._flat_output_types)
#     744   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 745 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\jason\miniconda3\envs\pdd9\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3421, in make_iterator(dataset, iterator, name)
#    3419 if tld.is_eager:
#    3420   try:
# -> 3421     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3422       _ctx, "MakeIterator", name, dataset, iterator)
#    3423     return _result
#    3424   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
